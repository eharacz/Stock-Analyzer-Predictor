# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib
import json
import requests
import time
from tqdm import tqdm

# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_datareader import data, wb
import pandas_datareader.data as web

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %% [markdown]
# # ---------------------

# %%
close_px = df['Adj Close']
mavg = close_px.rolling(window=100).mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ec913a55bc6b> in <module>
# ----> 1 close_px = df['Adj Close']
#       2 mavg = close_px.rolling(window=100).mean()
#
# NameError: name 'df' is not defined

# %%
mavg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9b43a612e964> in <module>
# ----> 1 mavg
#
# NameError: name 'mavg' is not defined

# %%
rets = close_px / close_px.shift(1) - 1

# %%
rets.plot(label='return')

# %%
dfcomp = web.DataReader(stock_list,'yahoo',start=start,end=end)['Adj Close']

# %% [markdown]
# # S&P500 Stock Collection (Wikipedia)

# %%
wiki = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')

# %%
pd.set_option('display.max_rows', 505)

# %%
wiki1 = wiki[0]

# %%
wiki1
# Out:
#     Ticker Symbol                                Security SEC filings  \
# 0             MMM                              3M Company     reports
# 1             ABT                     Abbott Laboratories     reports
# 2            ABBV                             AbbVie Inc.     reports
# 3            ABMD                             ABIOMED Inc     reports
# 4             ACN                           Accenture plc     reports
# 5            ATVI                     Activision Blizzard     reports
# 6            ADBE                       Adobe Systems Inc     reports
# 7             AMD              Advanced Micro Devices Inc     reports
# 8             AAP                      Advance Auto Parts     reports
# 9             AES                                AES Corp     reports
# 10            AFL                               AFLAC Inc     reports
# 11              A                Agilent Technologies Inc     reports
# ...

# %%
tickers = wiki1['Ticker Symbol']

# %%
ticker_list = list(wiki1['Ticker Symbol'])

# %%
ticker_list[69] = 'BRK-B'
ticker_list[81] = 'BF-B'

# %%
ticker_list
# Out:
# ['MMM',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADBE',
#  'AMD',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALXN',
#  'ALGN',
#  'ALLE',
#  'AGN',
#  'ADS',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'AIV',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ADM',
#  'ARNC',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'ATO',
#  'T',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BLL',
#  'BAC',
#  'BK',
#  'BAX',
#  'BDX',
#  'BRK-B',
#  'BBY',
#  'BIIB',
#  'BLK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BF-B',
#  'CHRW',
#  'COG',
#  'CDNS',
#  'CPB',
#  'COF',
#  'CPRI',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
# ...

# %%
tickers_marketwatch=list(wiki1['Ticker Symbol'])

# %%
tickers_marketwatch

# %% [markdown]
# # Stock Data Pull (Yahoo!)

# %%
#Pull all the info for all the stocks. Add column for the ticker. Concat to master df

start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2019, 12, 31)

df = web.DataReader("AAPL", 'yahoo', start, end)

def data_pull(tick):
    df = web.DataReader(f'{tick}', 'yahoo', start, end)
    df['Company']= f'{tick}'
    return df

stock_df_list = []
for t in ticker_list: 
    print(t)
    tick = f'{t}'
    stock = data_pull(f'{t}')
    stock_df_list.append(stock)
    time.sleep(1) 

len(stock_df_list)
