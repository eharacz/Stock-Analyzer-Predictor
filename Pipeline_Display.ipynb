# %%
import os
import sys
import pandas as pd
#import matplotlib.pyplot as plt

# %%
import plotly.graph_objects as go

# %%
import prophet_pipeline as prophet

# %%
pd.options.display.max_rows = 365

# %%
ticker = input('Enter: ')
# Out:
# Enter: AAPL

# %%
prophet.predict_stock_price(ticker)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# <div>
#
#
#             <div id="883de302-bc37-410a-9660-8b2f147c18f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("883de302-bc37-410a-9660-8b2f147c18f6")) {
#                     Plotly.newPlot(
#                         '883de302-bc37-410a-9660-8b2f147c18f6',
# ...
